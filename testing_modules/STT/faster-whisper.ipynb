# %%
import os, sys

try:
    # works when running a .py file
    SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    # fallback for Jupyter or interactive mode
    SCRIPT_DIR = os.getcwd()

# project root = two levels up
PROJECT_ROOT = os.path.abspath(os.path.join(SCRIPT_DIR, "../../"))

# add project root to sys.path so imports work
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

from config_loader import get_path

MODEL_PATH = get_path("tts_coqui_en_large_tf")
SCORER_PATH = get_path("tts_coqui_en_large_scorer")

print("TF model:", MODEL_PATH)
print("Scorer:", SCORER_PATH)
print("project root",PROJECT_ROOT)
# Out:
# TF model: /home/prot/Projects/Project-ALB/Models/STT/coqui/model.tflite
# Scorer: /home/prot/Projects/Project-ALB/tModels/STT/coqui/huge-vocabulary.scorer
# project root /home/prot/Projects
