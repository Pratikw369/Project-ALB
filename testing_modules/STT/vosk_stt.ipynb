# %%
import sounddevice as sd
import queue
import json
from vosk import Model, KaldiRecognizer

q = queue.Queue()
def callback(indata, frames, time, status):
    if status:
        print(status)
    q.put(bytes(indata))

model = Model("model")  # path to vosk model folder
rec = KaldiRecognizer(model, 16000)

with sd.RawInputStream(samplerate=16000, blocksize=8000, dtype='int16',
                       channels=1, callback=callback):
    print("Listening...")
    while True:
        data = q.get()
        if rec.AcceptWaveform(data):
            res = json.loads(rec.Result())
            print("You said:", res.get("text", ""))
# Out:
# ERROR (VoskAPI:Model():model.cc:122) Folder 'model' does not contain model files. Make sure you specified the model path properly in Model constructor. If you are not sure about relative path, use absolute path specification.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9         print(status)
#      10     q.put(bytes(indata))
# ---> 12 model = Model("model")  # path to vosk model folder
#      13 rec = KaldiRecognizer(model, 16000)
#      15 with sd.RawInputStream(samplerate=16000, blocksize=8000, dtype='int16',
#      16                        channels=1, callback=callback):
#
# File ~/.local/lib/python3.10/site-packages/vosk/__init__.py:57, in Model.__init__(self, model_path, model_name, lang)
#      55     self._handle = _c.vosk_model_new(model_path.encode("utf-8"))
#      56 if self._handle == _ffi.NULL:
# ---> 57     raise Exception("Failed to create a model")
#
# Exception: Failed to create a model
